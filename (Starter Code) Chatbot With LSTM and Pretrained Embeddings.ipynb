# %% [markdown]
# # LSTM Bot
#
# ## Project Overview
#
# In this project, you will build a chatbot that can converse with you at the command line. The chatbot will use a Sequence to Sequence text generation architecture with an LSTM as it's memory unit. You will also learn to use pretrained word embeddings to improve the performance of the model. At the conclusion of the project, you will be able to show your chatbot to potential employers.
#
# Additionally, you have the option to use pretrained word embeddings in your model. We have loaded Brown Embeddings from Gensim in the starter code below. You can compare the performance of your model with pre-trained embeddings against a model without the embeddings.
#
#
#
# ---
#
#
#
# A sequence to sequence model (Seq2Seq) has two components:
# - An Encoder consisting of an embedding layer and LSTM unit.
# - A Decoder consisting of an embedding layer, LSTM unit, and linear output unit.
#
# The Seq2Seq model works by accepting an input into the Encoder, passing the hidden state from the Encoder to the Decoder, which the Decoder uses to output a series of token predictions.
#
# ## Dependencies
#
# - Pytorch
# - Numpy
# - Pandas
# - NLTK
# - Gzip
# - Gensim
#
#
# Please choose a dataset from the Torchtext website. We recommend looking at the Squad dataset first. Here is a link to the website where you can view your options:
#
# - https://pytorch.org/text/stable/datasets.html

# %%
# !pip install torchdata==0.3.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting torchdata==0.3.0
#   Downloading torchdata-0.3.0-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 3.0 MB/s eta 0:00:011
# Requirement already satisfied: torch==1.11.0 in /opt/conda/lib/python3.7/site-packages (from torchdata==0.3.0) (1.11.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from torchdata==0.3.0) (2.23.0)
# Requirement already satisfied: urllib3>=1.25 in /opt/conda/lib/python3.7/site-packages (from torchdata==0.3.0) (1.25.7)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.7/site-packages (from torch==1.11.0->torchdata==0.3.0) (3.7.4.1)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->torchdata==0.3.0) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->torchdata==0.3.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->torchdata==0.3.0) (2019.11.28)
# Installing collected packages: torchdata
# Successfully installed torchdata-0.3.0

# %%
import gensim
import nltk
import numpy as np
import pandas as pd
import torch
import random
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
from nltk.corpus import brown
from torchtext.datasets import SQuAD1
from collections import defaultdict
from nltk.tokenize import RegexpTokenizer
from nltk.stem import PorterStemmer
from torch import nn
from torch.utils.tensorboard import SummaryWriter

# %%
def load_df(train_iter):
    '''
    This function loads the dataset into a Pandas DataFrame for processing.
    '''
    questions = []
    answers = []

    for index, (context, question, ans, indices) in enumerate(train_iter):
        if ans[0]:
            questions.append(question)
            answers.append(ans[0])

    df = pd.DataFrame({"question": questions, "answer": answers})
    return df

# %%
random.seed(42)
train_data = SQuAD1(root='.', split=('train'))
train_data = load_df(train_data)

# %%
class Vocab:
    def __init__(self, name, trimMinValue, trimMaxValue):
        self.name = name
        self.index = {0:"<sos>", 1:"<eos>", 2:"<pad>", 3:"<unk>"}
        self.words = {"<sos>":0, "<eos>":1, "<pad>":2, "<unk>":3}
        self.wordsCounter = {"<sos>":0, "<eos>":0, "<pad>":0, "<unk>":0}
        self.count = 4
        self.tokenizer = RegexpTokenizer(r'\w+')
        self.stemmer = PorterStemmer()
        self.trimMinValue = trimMinValue
        self.trimMaxValue = trimMaxValue
    
    def indexWord(self, word):
        if word not in self.words:
            self.words[word] = self.count
            self.wordsCounter[word] = 1
            self.index[self.count] = word
            self.count += 1
        else:
            self.wordsCounter[word] += 1
    
    def addSentence(self, sentence, maxlen):
        tokens = self.tokenizeSentence(sentence)
        for token in tokens[: maxlen-2]:
            self.indexWord(token)
    
    def tokenizeSentence(self, sentence): 
        ss = sentence.lower()
        ss = self.tokenizer.tokenize(ss)
        ss = [self.stemmer.stem(w) for w in ss if not w.isdigit()]
        return ss
    
    def trimVocab(self):
        trimmedIndex = {0:"<sos>", 1:"<eos>", 2:"<pad>", 3:"<unk>"}
        trimmedWords = {"<sos>":0, "<eos>":1, "<pad>":2, "<unk>":3}
        trimmedWordsCounter = {"<sos>":0, "<eos>":0, "<pad>":0, "<unk>":0}
        trimmedCount = 4
        for i in range(4,self.count):
            if (self.wordsCounter[self.index[i]] >= self.trimMinValue) and (self.wordsCounter[self.index[i]] <= self.trimMaxValue):
                trimmedWords[self.index[i]] = trimmedCount
                trimmedWordsCounter[self.index[i]] = self.wordsCounter[self.index[i]]
                trimmedIndex[trimmedCount] = self.index[i]
                trimmedCount += 1
        self.index = trimmedIndex
        self.words = trimmedWords
        self.wordsCounter = trimmedWordsCounter
        self.count = trimmedCount
    
        
    def prepareSentence(self, sentence):
        tokens = self.tokenizeSentence(sentence)
        sentence = []
        for token in tokens:
            if token in self.words:
                sentence.append(token)
            else:
                sentence.append("<unk>")
        sentence.insert(0, "<sos>")
        sentence.append("<eos>")
        
        return sentence
    
    def paddSentence(self, sentence, maxlen):
        paddedSentence = []
        if len(sentence)>maxlen:
            for i in range(maxlen-1):
                paddedSentence.append(sentence[i])
            paddedSentence.append("<eos>")
        elif len(sentence)<=maxlen:
            paddedSentence = sentence
            for i in range(len(sentence),maxlen):
                paddedSentence.append("<pad>")
        return paddedSentence
    
    def paddSentences(self, sentences, maxlen):
        paddedSentences = []
        for sentence in sentences:
            paddedSentences.append(self.paddSentence(sentence, maxlen))
        return paddedSentences
        
    def indexSentence(self,sentence):
        return [self.words[w] for w in sentence]
    
    def wordSentence(self,sentence):
        return [self.index[w] for w in sentence]

# %%
vocab = Vocab(name='SQuAD1Vocab', trimMinValue = 10, trimMaxValue = 1500)
maxlenQ = 10
maxlenA = 5

# %%
for i, r in train_data.iterrows():
    question_text = vocab.addSentence(r["question"], maxlenQ)
    answer_text = vocab.addSentence(r["answer"], maxlenA)
print("Added {} words to our vocabulary".format(vocab.count))
# Out:
# Added 32990 words to our vocabulary

# %%
vocab.trimVocab()
print("Remain {} words in our vocabulary after trimming".format(vocab.count))
# Out:
# Remain 5458 words in our vocabulary after trimming

# %%
trainQ = []
trainA = []

for i,r, in train_data.iterrows():
    trainQ.append(vocab.prepareSentence(r["question"]))
    trainA.append(vocab.prepareSentence(r["answer"]))

# %%
print(trainQ[3])
print(trainA[3])
#Padd sentences
trainQ = vocab.paddSentences(trainQ, maxlenQ)
trainA = vocab.paddSentences(trainA, maxlenA)
print(trainQ[3])
print(trainA[3])
# Out:
# ['<sos>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', 'notr', 'dame', '<eos>']
# ['<sos>', '<unk>', 'marian', 'place', '<unk>', 'prayer', '<unk>', 'reflect', '<eos>']
# ['<sos>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', 'notr', 'dame', '<eos>', '<pad>']
# ['<sos>', '<unk>', 'marian', 'place', '<eos>']

# %%
trainQtok = []
trainAtok = []

for sentence in trainQ:
    trainQtok.append(vocab.indexSentence(sentence))
for sentence in trainA:
    trainAtok.append(vocab.indexSentence(sentence))

print(trainQtok[3])
# Out:
# [0, 3, 3, 3, 3, 3, 10, 11, 1, 2]

# %%
def get_batches(questions, answers, batch_size):
    n_batches = len(questions) // batch_size

    # Consider only full batches
    questions = questions[:n_batches * batch_size]
    answers = answers[:n_batches * batch_size]

    for idx in range(0, len(questions), batch_size):
        questions_batch = np.array(questions[idx:idx + batch_size])
        answers_batch = np.array(answers[idx:idx + batch_size])
        yield questions_batch, answers_batch

# %%
class Encoder(nn.Module):
    
    def __init__(self, input_size, hidden_size, embedding_size, num_layers, p):
        super(Encoder, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.embedding_size = embedding_size
        self.num_layers = num_layers

        self.dropout = nn.Dropout(p)
        self.embedding = nn.Embedding(self.input_size, self.embedding_size)
        self.lstm = nn.LSTM(self.embedding_size, self.hidden_size, self.num_layers, dropout=p, batch_first=True)

    def forward(self, i):
        embedding = self.dropout(self.embedding(i))
        output, (hidden, cell) = self.lstm(embedding)
        return hidden, cell


class Decoder(nn.Module):
      
    def __init__(self, hidden_size, embedding_size, output_size, num_layers, p):
        super(Decoder, self).__init__()
        self.hidden_size = hidden_size
        self.embedding_size = embedding_size
        self.output_size = output_size
        self.num_layers = num_layers

        self.dropout = nn.Dropout(p)
        self.embedding = nn.Embedding(self.output_size, self.embedding_size)
        self.lstm = nn.LSTM(self.embedding_size, self.hidden_size, self.num_layers, dropout=p, batch_first=True)
        self.fc = nn.Linear(self.hidden_size, self.output_size)    
        
    def forward(self, i, hidden, cell):
        i = i.unsqueeze(-1)
        embedding = self.dropout(self.embedding(i))
        output, (hidden, cell) = self.lstm(embedding, (hidden, cell))
        prediction = self.fc(output.squeeze(1))
        return prediction, hidden, cell
        

class LSTMSeq2Seq(nn.Module):
    def __init__(self, encoder, decoder, output_size, device):
        super(LSTMSeq2Seq, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.output_size = output_size
        self.device = device
        
    def forward(self, src, trg, teacher_forcing_ratio):
        batch_size = src.shape[0]
        trg_len = trg.shape[1]
        trg_vocab_size = self.output_size

        prediction = torch.zeros(batch_size, trg_len, trg_vocab_size).to(self.device)

        hidden, cell = self.encoder(src)

        input = trg[:, 0]

        for t in range(1, trg_len):
            output, hidden, cell = self.decoder(input, hidden, cell)
            prediction[:, t] = output
            teacher_force = random.random() < teacher_forcing_ratio
            top1 = output.argmax(1)
            input = trg[:, t] if teacher_force else top1

        return prediction

# %%
num_epochs = 200
batch_size = 256
learning_rate = 0.0001

input_size = vocab.count
output_size = vocab.count
embedding_size = 256
hidden_size = 1024
num_layers = 2
p_dropout = 0.5
teacher_forcing_ratio = 0.5

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)

enc = Encoder(input_size, hidden_size, embedding_size, num_layers, p_dropout)
dec = Decoder(hidden_size, embedding_size, output_size, num_layers, p_dropout)

model = LSTMSeq2Seq(enc, dec, output_size, device).to(device)
print(model)
# Out:
# cuda
# LSTMSeq2Seq(
#   (encoder): Encoder(
#     (dropout): Dropout(p=0.5, inplace=False)
#     (embedding): Embedding(5458, 256)
#     (lstm): LSTM(256, 1024, num_layers=2, batch_first=True, dropout=0.5)
#   )
#   (decoder): Decoder(
#     (dropout): Dropout(p=0.5, inplace=False)
#     (embedding): Embedding(5458, 256)
#     (lstm): LSTM(256, 1024, num_layers=2, batch_first=True, dropout=0.5)
#     (fc): Linear(in_features=1024, out_features=5458, bias=True)
#   )
# )

# %%
optimizer = torch.optim.Adam(model.parameters(),lr=learning_rate)
criterion = nn.CrossEntropyLoss(ignore_index = vocab.words['<pad>'])

# %%
lr_scheduler = ReduceLROnPlateau(optimizer, factor=0.1, patience=5)

# %%
def train(model, optimizer, criterion, clip):
    model.train()
    epoch_loss = 0
    l = 0
    
    for x, y in get_batches(trainQtok, trainAtok, batch_size):
        inputs = torch.from_numpy(x).to(device)
        targets = torch.from_numpy(y).to(device)

        optimizer.zero_grad()
        
        output = model(inputs, targets, teacher_forcing_ratio)
        
        loss = criterion(output[:, 1:].reshape(-1, output.shape[-1]), targets[:, 1:].reshape(-1))
        
        loss.backward()
        
        torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
        
        optimizer.step()
        
        epoch_loss += loss.item()
        l += 1

        if l == 1:
            for i in range(5):
                target = targets[i].detach().cpu().numpy()
                answer = output[i].argmax(dim=1).detach().cpu().numpy()
                print("Answer: " + str(vocab.wordSentence(answer)) + " | " + "Target: " + str(vocab.wordSentence(target)))
        
    return epoch_loss / l

# %%
#Tensorboard
writer = SummaryWriter(log_dir="./runs")

# %%
best_train_loss = float('inf')
clip = 1
save_path = 'chatbot_model.pt'

for epoch in range(num_epochs):
    train_loss = train(model, optimizer, criterion, clip)
    
    if train_loss < best_train_loss:
        best_train_loss = train_loss
        torch.save(model.state_dict(), save_path)

    print(f"Epoch: {epoch} | TrainLoss: {train_loss} | BestTrainLoss: {best_train_loss}")
    writer.add_scalar("Loss/train", train_loss, epoch)
    
    lr_scheduler.step(train_loss)
    
writer.flush()
writer.close()
# Out:
# Answer: ['<sos>', 'financ', 'spot', 'n', 'displac'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', 'affirm', 'rough', 'napoleon', 'napoleon'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', 'sherman', 'sherman', 'vocabulari', 'parallel'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', 'jazz', 'california', 'english', 'rousseau'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', 'rca', 'napoleon', 'iraq', 'kazakhstan'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 0 | TrainLoss: 4.4051996734407215 | BestTrainLoss: 4.4051996734407215
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 1 | TrainLoss: 4.1240381901724295 | BestTrainLoss: 4.1240381901724295
# Answer: ['<sos>', '<unk>', '<eos>', '<unk>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 2 | TrainLoss: 4.103009645701849 | BestTrainLoss: 4.103009645701849
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 3 | TrainLoss: 4.091935585813912 | BestTrainLoss: 4.091935585813912
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 4 | TrainLoss: 4.082723952176278 | BestTrainLoss: 4.082723952176278
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 5 | TrainLoss: 4.0700429141172885 | BestTrainLoss: 4.0700429141172885
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 6 | TrainLoss: 4.05854806844254 | BestTrainLoss: 4.05854806844254
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 7 | TrainLoss: 4.0468333401875185 | BestTrainLoss: 4.0468333401875185
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 8 | TrainLoss: 4.034401911741112 | BestTrainLoss: 4.034401911741112
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 9 | TrainLoss: 4.021316130258883 | BestTrainLoss: 4.021316130258883
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 10 | TrainLoss: 4.001763511122319 | BestTrainLoss: 4.001763511122319
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 11 | TrainLoss: 3.981087979517485 | BestTrainLoss: 3.981087979517485
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 12 | TrainLoss: 3.955373876276072 | BestTrainLoss: 3.955373876276072
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<eos>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 13 | TrainLoss: 3.9306540984159324 | BestTrainLoss: 3.9306540984159324
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 14 | TrainLoss: 3.907412226437128 | BestTrainLoss: 3.907412226437128
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<eos>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 15 | TrainLoss: 3.8812331714128194 | BestTrainLoss: 3.8812331714128194
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 16 | TrainLoss: 3.856450473355968 | BestTrainLoss: 3.856450473355968
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 17 | TrainLoss: 3.8320619188554104 | BestTrainLoss: 3.8320619188554104
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 18 | TrainLoss: 3.809533465675443 | BestTrainLoss: 3.809533465675443
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 19 | TrainLoss: 3.7874127724017317 | BestTrainLoss: 3.7874127724017317
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<eos>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 20 | TrainLoss: 3.766184677854616 | BestTrainLoss: 3.766184677854616
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 21 | TrainLoss: 3.7452314109133003 | BestTrainLoss: 3.7452314109133003
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 22 | TrainLoss: 3.7244002874831708 | BestTrainLoss: 3.7244002874831708
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 23 | TrainLoss: 3.7062682234055813 | BestTrainLoss: 3.7062682234055813
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 24 | TrainLoss: 3.6824486158047502 | BestTrainLoss: 3.6824486158047502
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 25 | TrainLoss: 3.662130348166527 | BestTrainLoss: 3.662130348166527
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 26 | TrainLoss: 3.65173920344191 | BestTrainLoss: 3.65173920344191
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 27 | TrainLoss: 3.6253734143853884 | BestTrainLoss: 3.6253734143853884
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 28 | TrainLoss: 3.6008886238287765 | BestTrainLoss: 3.6008886238287765
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 29 | TrainLoss: 3.5803509107110094 | BestTrainLoss: 3.5803509107110094
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 30 | TrainLoss: 3.559082185315807 | BestTrainLoss: 3.559082185315807
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<eos>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 31 | TrainLoss: 3.5416742005543402 | BestTrainLoss: 3.5416742005543402
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 32 | TrainLoss: 3.5200271864383543 | BestTrainLoss: 3.5200271864383543
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 33 | TrainLoss: 3.49823130153076 | BestTrainLoss: 3.49823130153076
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 34 | TrainLoss: 3.4824648370519715 | BestTrainLoss: 3.4824648370519715
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 35 | TrainLoss: 3.464968320221929 | BestTrainLoss: 3.464968320221929
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 36 | TrainLoss: 3.4497532760887815 | BestTrainLoss: 3.4497532760887815
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 37 | TrainLoss: 3.4260231639906675 | BestTrainLoss: 3.4260231639906675
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 38 | TrainLoss: 3.4014191014027735 | BestTrainLoss: 3.4014191014027735
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 39 | TrainLoss: 3.387509072036074 | BestTrainLoss: 3.387509072036074
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 40 | TrainLoss: 3.3641305785430107 | BestTrainLoss: 3.3641305785430107
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 41 | TrainLoss: 3.3380147344187687 | BestTrainLoss: 3.3380147344187687
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 42 | TrainLoss: 3.3177120887745195 | BestTrainLoss: 3.3177120887745195
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 43 | TrainLoss: 3.298182983844601 | BestTrainLoss: 3.298182983844601
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 44 | TrainLoss: 3.2742732902716476 | BestTrainLoss: 3.2742732902716476
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 45 | TrainLoss: 3.259779803934153 | BestTrainLoss: 3.259779803934153
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 46 | TrainLoss: 3.233259467353598 | BestTrainLoss: 3.233259467353598
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 47 | TrainLoss: 3.207784453330681 | BestTrainLoss: 3.207784453330681
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 48 | TrainLoss: 3.195841185530724 | BestTrainLoss: 3.195841185530724
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 49 | TrainLoss: 3.1706518192737425 | BestTrainLoss: 3.1706518192737425
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 50 | TrainLoss: 3.152010853527582 | BestTrainLoss: 3.152010853527582
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 51 | TrainLoss: 3.1360614327659384 | BestTrainLoss: 3.1360614327659384
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 52 | TrainLoss: 3.1117589257613956 | BestTrainLoss: 3.1117589257613956
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 53 | TrainLoss: 3.0913499928357306 | BestTrainLoss: 3.0913499928357306
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 54 | TrainLoss: 3.0674579415405008 | BestTrainLoss: 3.0674579415405008
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 55 | TrainLoss: 3.057597580011825 | BestTrainLoss: 3.057597580011825
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 56 | TrainLoss: 3.034538341544525 | BestTrainLoss: 3.034538341544525
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 57 | TrainLoss: 3.006671595294573 | BestTrainLoss: 3.006671595294573
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 58 | TrainLoss: 2.9859224153540986 | BestTrainLoss: 2.9859224153540986
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 59 | TrainLoss: 2.973490638342517 | BestTrainLoss: 2.973490638342517
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 60 | TrainLoss: 2.95164296152996 | BestTrainLoss: 2.95164296152996
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<eos>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 61 | TrainLoss: 2.9306594698052657 | BestTrainLoss: 2.9306594698052657
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 62 | TrainLoss: 2.9209232288494444 | BestTrainLoss: 2.9209232288494444
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 63 | TrainLoss: 2.9037971231672497 | BestTrainLoss: 2.9037971231672497
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 64 | TrainLoss: 2.881197596154018 | BestTrainLoss: 2.881197596154018
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<eos>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 65 | TrainLoss: 2.8656033570306345 | BestTrainLoss: 2.8656033570306345
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 66 | TrainLoss: 2.848311476540147 | BestTrainLoss: 2.848311476540147
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 67 | TrainLoss: 2.824972752939191 | BestTrainLoss: 2.824972752939191
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 68 | TrainLoss: 2.8118108922277973 | BestTrainLoss: 2.8118108922277973
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 69 | TrainLoss: 2.7841093003401283 | BestTrainLoss: 2.7841093003401283
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 70 | TrainLoss: 2.776845043165642 | BestTrainLoss: 2.776845043165642
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<eos>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 71 | TrainLoss: 2.7566154386565 | BestTrainLoss: 2.7566154386565
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 72 | TrainLoss: 2.730022984638549 | BestTrainLoss: 2.730022984638549
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 73 | TrainLoss: 2.7100576357534756 | BestTrainLoss: 2.7100576357534756
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 74 | TrainLoss: 2.684244670365986 | BestTrainLoss: 2.684244670365986
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 75 | TrainLoss: 2.6613087549544217 | BestTrainLoss: 2.6613087549544217
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# ...
# Epoch: 174 | TrainLoss: 0.9634624283913283 | BestTrainLoss: 0.9634624283913283
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', 'build', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<unk>', 'marian', 'place', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', 'protest', 'church', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 175 | TrainLoss: 0.9454926217508595 | BestTrainLoss: 0.9454926217508595
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', 'main', 'build', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<unk>', 'marian', 'place', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 176 | TrainLoss: 0.9310601421615534 | BestTrainLoss: 0.9310601421615534
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<eos>', '<unk>', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', 'marian', 'place', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', 'palac', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 177 | TrainLoss: 0.9160521229108175 | BestTrainLoss: 0.9160521229108175
# Answer: ['<sos>', 'michael', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', 'main', 'build', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', 'marian', 'place', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', 'golden', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 178 | TrainLoss: 0.8987361800078063 | BestTrainLoss: 0.8987361800078063
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', 'main', 'build', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', 'marian', 'place', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', 'da', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 179 | TrainLoss: 0.8966907782164234 | BestTrainLoss: 0.8966907782164234
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', 'main', 'build', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<unk>', 'marian', 'place', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', 'museum', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 180 | TrainLoss: 0.8839635042070645 | BestTrainLoss: 0.8839635042070645
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', 'church', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', 'main', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', 'marian', 'place', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', 'golden', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 181 | TrainLoss: 0.8729418210293117 | BestTrainLoss: 0.8729418210293117
# Answer: ['<sos>', 'michael', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', 'build', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', 'place', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', 'golden', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 182 | TrainLoss: 0.8541035555433809 | BestTrainLoss: 0.8541035555433809
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', 'marian', 'place', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', 'golden', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 183 | TrainLoss: 0.8482403174826973 | BestTrainLoss: 0.8482403174826973
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', 'colleg', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', 'main', 'build', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', 'marian', 'place', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', 'golden', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 184 | TrainLoss: 0.8466683705473503 | BestTrainLoss: 0.8466683705473503
# Answer: ['<sos>', 'michael', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', 'build', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<unk>', 'marian', 'place', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', 'golden', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 185 | TrainLoss: 0.8288463428180818 | BestTrainLoss: 0.8288463428180818
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', 'build', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<unk>', 'marian', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', 'standard', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 186 | TrainLoss: 0.8083804643642135 | BestTrainLoss: 0.8083804643642135
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', 'age', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', 'marian', 'place', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', 'golden', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 187 | TrainLoss: 0.79725074942349 | BestTrainLoss: 0.79725074942349
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', 'build', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', 'marian', 'place', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', 'golden', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 188 | TrainLoss: 0.7916389796120381 | BestTrainLoss: 0.7916389796120381
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', 'marian', 'place', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', 'golden', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 189 | TrainLoss: 0.7812046133286772 | BestTrainLoss: 0.7812046133286772
# Answer: ['<sos>', 'soviet', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', 'northeast', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', 'main', 'servic', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', 'marian', 'place', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', 'lake', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 190 | TrainLoss: 0.7696754515868182 | BestTrainLoss: 0.7696754515868182
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', 'famili', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', 'marian', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', 'news', 'day', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 191 | TrainLoss: 0.7608669666867507 | BestTrainLoss: 0.7608669666867507
# Answer: ['<sos>', '<unk>', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', 'main', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<unk>', 'marian', '<unk>', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', 'golden', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 192 | TrainLoss: 0.7578802390231026 | BestTrainLoss: 0.7578802390231026
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', 'intern', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', 'main', 'build', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<unk>', 'marian', 'place', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', 'ladi', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 193 | TrainLoss: 0.7451368893621958 | BestTrainLoss: 0.7451368893621958
# Answer: ['<sos>', 'michael', '<unk>', '<eos>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', 'research', 'colleg', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', 'build', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<unk>', 'marian', 'place', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 194 | TrainLoss: 0.7292997125993695 | BestTrainLoss: 0.7292997125993695
# Answer: ['<sos>', 'america', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', 'church', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', 'main', '<eos>', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<unk>', 'marian', 'place', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', 'golden', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 195 | TrainLoss: 0.7294767813550102 | BestTrainLoss: 0.7292997125993695
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', 'main', 'build', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', 'marian', 'place', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', 'golden', 'golden', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 196 | TrainLoss: 0.7144367528414866 | BestTrainLoss: 0.7144367528414866
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<eos>', 'american', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', 'marian', 'place', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', 'golden', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 197 | TrainLoss: 0.7040276193653631 | BestTrainLoss: 0.7040276193653631
# Answer: ['<sos>', 'han', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', 'build', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', 'marian', 'place', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', 'golden', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 198 | TrainLoss: 0.6913235902960537 | BestTrainLoss: 0.6913235902960537
# Answer: ['<sos>', '<unk>', '<unk>', '<unk>', '<eos>'] | Target: ['<sos>', 'saint', '<unk>', '<unk>', '<eos>']
# Answer: ['<sos>', '<unk>', '<unk>', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'copper', 'statu', '<eos>']
# Answer: ['<sos>', '<unk>', 'main', 'build', '<eos>'] | Target: ['<sos>', '<unk>', 'main', 'build', '<eos>']
# Answer: ['<sos>', '<eos>', 'marian', 'place', '<eos>'] | Target: ['<sos>', '<unk>', 'marian', 'place', '<eos>']
# Answer: ['<sos>', '<unk>', 'golden', 'statu', '<eos>'] | Target: ['<sos>', '<unk>', 'golden', 'statu', '<eos>']
# Epoch: 199 | TrainLoss: 0.6897831955674099 | BestTrainLoss: 0.6897831955674099
